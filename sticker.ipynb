# %%
import cv2

# %%
img_path = "C:/Users/prokj/Downloads/lsg.jpg"
img = cv2.imread(img_path, 0)

# %%
img.shape
# Out:
# (582, 455)

# %%
cv2.imshow(img_path, img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#오 여기서는 성공!!

# %%
cv2.imwrite('leesg.jpg', img)
# Out:
# True

# %%
import cv2

img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
cv2.imshow('image',img)
k = cv2.waitKey(0) & 0xFF
if k == 27: # esc key
    cv2.destroyAllWindow()
elif k == ord('s'): # 's' key
    cv2.imwrite('lenagray.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# Matplotlib 사용하기

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread(img_path, cv2.IMREAD_COLOR)

plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img = cv2.imread(img_path, -1)
b,g,r = cv2.split(img)
img2 = cv2.merge([r,g,b])


plt.imshow(img2)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# 링크에서 알려준대로 이미지 다뤄보기 성공.... ㅎㅎ;;
